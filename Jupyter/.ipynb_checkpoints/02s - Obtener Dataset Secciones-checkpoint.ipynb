# %%
import random
import numpy as np
r_state = 42
random.seed(r_state) 
np.random.seed(r_state)

import geopandas as gpd
import pandas as pd
import numpy as np
from functools import reduce

import os

# %% [markdown]
# ## V1 Crear dataset con 60 predictores -> 35 registros en 2011 y 115 en 2021

# %%
# Ruta donde están los CSV
ruta = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\Procesados\Secciones"
anio_2011 = "2011"  # 2011
anio_2021 = "2021"  # 2021

# Crear una lista para almacenar los DataFrames
dataframes_2011 = []
dataframes_2021 = []

# Iterar sobre los archivos en la ruta
for archivo in os.listdir(ruta):
    # Verificar si el archivo es un CSV y comienza con el año
    if archivo.endswith('.csv') and archivo.startswith(anio_2011):
        # Leer el archivo y agregarlo a la lista de DataFrames
        df = pd.read_csv(os.path.join(ruta, archivo),sep=";")
        dataframes_2011.append(df)
        
        
    if archivo.endswith('.csv') and archivo.startswith(anio_2021):
        # Leer el archivo y agregarlo a la lista de DataFrames
        df = pd.read_csv(os.path.join(ruta, archivo),sep=";")
        dataframes_2021.append(df)

# Unir todos los DataFrames por la columna 'NUMSECCENS' utilizando reduce 
df_2011 = reduce(lambda left, right: pd.merge(left, right, on="NUMSECCENS"), dataframes_2011)
df_2021 = reduce(lambda left, right: pd.merge(left, right, on="NUMSECCENS"), dataframes_2021)
#print(df_2011)#35rows x 56 columns Tenemos 35 secciones con todos los datos
#print(df_2021)#123rows x 56 columns Tenemos 123 secciones con todos los datos hasta aqui

#Incluir scores
path_scores = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Scores\Scores-Secciones.csv"
df_scores = pd.read_csv(path_scores,sep=";")
df_scores_2011 =  df_scores[["NUMSECCENS","SES_11","kw_pct_11","he_pct_11","median_price_inf_11"]]
df_scores_2021 =  df_scores[["NUMSECCENS","SES_21","kw_pct_21","he_pct_21","median_price_inf_21"]]

df_2011 = pd.merge(df_2011, df_scores_2011, on='NUMSECCENS')
df_2021 = pd.merge(df_2021, df_scores_2021, on='NUMSECCENS')

#print(df_2011)#35rows x 60
#print(df_2021)#115rows x 60

# %%
df_2011.to_csv(os.path.join(ruta, "df_2011.csv"),index=False,sep=";")
df_2021.to_csv(os.path.join(ruta, "df_2021.csv"),index=False,sep=";")

# %% [markdown]
# ## Crear Dataset con join left para visualizar datos disponibles en cada seccion

# %%
# Unir todos los DataFrames por la columna 'NUMSECCENS' utilizando reduce left
df_2011_left = reduce(lambda left, right: pd.merge(left, right, on="NUMSECCENS", how="left"), dataframes_2011)
df_2021_left = reduce(lambda left, right: pd.merge(left, right, on="NUMSECCENS", how="left"), dataframes_2021)

df_2011_left = pd.merge(df_2011_left, df_scores_2011, on='NUMSECCENS')
df_2021_left = pd.merge(df_2021_left, df_scores_2021, on='NUMSECCENS')

print(df_2011_left.count())
print(df_2021_left.count())
# Out:
# NUMSECCENS                                                                                                                                         425
# 15-19                                                                                                                                              425
# 20-34                                                                                                                                              425
# 35-64                                                                                                                                              425
# 65+                                                                                                                                                425
# Casado/a                                                                                                                                            54
# Divorciado/a o Separado/a                                                                                                                           54
# Soltero/a                                                                                                                                           54
# Viudo/a                                                                                                                                             54
# Hogar con un hombre solo de 65 años o más                                                                                                          425
# Hogar con un hombre solo menor de 65 años                                                                                                          425
# Hogar con un solo progenitor que convive con algún hijo menor de 25 años                                                                           425
# Hogar con un solo progenitor que convive con todos sus hijos de 25 años o más                                                                      425
# Hogar con una mujer sola de 65 años o más                                                                                                          425
# Hogar con una mujer sola menor de 65 años                                                                                                          425
# Hogar formado por pareja con hijos en donde algún hijo es menor de 25 años                                                                         425
# Hogar formado por pareja con hijos en donde todos los hijos de 25 años o más                                                                       425
# Hogar formado por pareja o un solo progenitor que convive con algún hijo menor de 25 años y otra(s) persona(a)                                     425
# Hogar formado por pareja sin hijos                                                                                                                 425
# Otro tipo de hogar                                                                                                                                 425
# Analfabetos                                                                                                                                        425
# Doctorado universitario                                                                                                                            425
# Educación postsecundaria no superior                                                                                                               425
# Educación primaria                                                                                                                                 425
# Enseñanzas de formación profesional, artes plásticas y diseño y deportivas de grado superior y equivalentes                                        425
# Estudios primarios incompletos                                                                                                                     425
# Grados universitarios de 240 créditos ECTS, diplomados universitarios, títulos propios universitarios de experto o especialista                    425
# Grados universitarios de más de 240 créditos ECTS, licenciados                                                                                     425
# Másteres, especialidades en Ciencias de la Salud por el sistema de residencia y similares                                                          425
# Primera etapa de educación secundaria y similar                                                                                                    425
# Segunda etapa de educación secundaria con orientación general                                                                                      425
# Segunda etapa de educación secundaria con orientación profesional                                                                                  425
# América Central, Sur y Caribe                                                                                                                       54
# América del Norte                                                                                                                                   54
# Asia                                                                                                                                                54
# Española                                                                                                                                            54
# Oceanía                                                                                                                                             54
# Resto de Europa                                                                                                                                     54
# Unión Europea (sin España)                                                                                                                          54
# África                                                                                                                                              54
# 1 - Directores y gerentes                                                                                                                          425
# 2 - Técnicos y profesionales científicos e intelectuales                                                                                           425
# 3 - Técnicos; profesionales de apoyo                                                                                                               425
# 4 - Empleados contables, administrativos y otros empleados de oficina                                                                              425
# 5 - Trabajadores de los servicios de restauración, personales, protección y vendedores                                                             425
# 6 - Trabajadores cualificados en el sector agrícola, ganadero, forestal y pesquero                                                                 425
# 7 - Artesanos y trabajadores cualificados de las industrias manufactureras y la construcción (excepto operadores de instalaciones y maquinaria)    425
# 8 - Operadores de instalaciones y maquinaria, y montadores                                                                                         425
# 9 - Ocupaciones elementales                                                                                                                        425
# En alquiler                                                                                                                                         42
# En propiedad                                                                                                                                        42
# Otro régimen de tenencia                                                                                                                            42
# Trabajador por cuenta ajena fijo o indefinido                                                                                                       54
# Trabajador por cuenta ajena temporal                                                                                                                54
# Trabajador por cuenta propia que emplea personal                                                                                                    54
# Trabajador por cuenta propia que no emplea personal                                                                                                 54
# SES_11                                                                                                                                             425
# kw_pct_11                                                                                                                                          425
# he_pct_11                                                                                                                                          425
# median_price_inf_11                                                                                                                                425
# dtype: int64
# NUMSECCENS                                                                                                                                         135
# 15-19                                                                                                                                              135
# 20-34                                                                                                                                              135
# 35-64                                                                                                                                              135
# 65+                                                                                                                                                135
# Casado/a                                                                                                                                           135
# Divorciado/a o Separado/a                                                                                                                          135
# Soltero/a                                                                                                                                          135
# Viudo/a                                                                                                                                            135
# Hogar con un hombre solo de 65 años o más                                                                                                          122
# Hogar con un hombre solo menor de 65 años                                                                                                          122
# Hogar con un solo progenitor que convive con algún hijo menor de 25 años                                                                           122
# Hogar con un solo progenitor que convive con todos sus hijos de 25 años o más                                                                      122
# Hogar con una mujer sola de 65 años o más                                                                                                          122
# Hogar con una mujer sola menor de 65 años                                                                                                          122
# Hogar formado por pareja con hijos en donde algún hijo es menor de 25 años                                                                         122
# Hogar formado por pareja con hijos en donde todos los hijos de 25 años o más                                                                       122
# Hogar formado por pareja o un solo progenitor que convive con algún hijo menor de 25 años y otra(s) persona(a)                                     122
# Hogar formado por pareja sin hijos                                                                                                                 122
# Otro tipo de hogar                                                                                                                                 122
# Analfabetos                                                                                                                                        135
# Doctorado universitario                                                                                                                            135
# Educación postsecundaria no superior                                                                                                               135
# Educación primaria                                                                                                                                 135
# Enseñanzas de formación profesional, artes plásticas y diseño y deportivas de grado superior y equivalentes                                        135
# Estudios primarios incompletos                                                                                                                     135
# Grados universitarios de 240 créditos ECTS, diplomados universitarios, títulos propios universitarios de experto o especialista                    135
# Grados universitarios de más de 240 créditos ECTS, licenciados                                                                                     135
# Másteres, especialidades en Ciencias de la Salud por el sistema de residencia y similares                                                          135
# Primera etapa de educación secundaria y similar                                                                                                    135
# Segunda etapa de educación secundaria con orientación general                                                                                      135
# Segunda etapa de educación secundaria con orientación profesional                                                                                  135
# América Central, Sur y Caribe                                                                                                                      135
# América del Norte                                                                                                                                  135
# Asia                                                                                                                                               135
# Española                                                                                                                                           135
# Oceanía                                                                                                                                            135
# Resto de Europa                                                                                                                                    135
# Unión Europea (sin España)                                                                                                                         135
# África                                                                                                                                             135
# 1 - Directores y gerentes                                                                                                                          135
# 2 - Técnicos y profesionales científicos e intelectuales                                                                                           135
# 3 - Técnicos; profesionales de apoyo                                                                                                               135
# 4 - Empleados contables, administrativos y otros empleados de oficina                                                                              135
# 5 - Trabajadores de los servicios de restauración, personales, protección y vendedores                                                             135
# 6 - Trabajadores cualificados en el sector agrícola, ganadero, forestal y pesquero                                                                 135
# 7 - Artesanos y trabajadores cualificados de las industrias manufactureras y la construcción (excepto operadores de instalaciones y maquinaria)    135
# 8 - Operadores de instalaciones y maquinaria, y montadores                                                                                         135
# 9 - Ocupaciones elementales                                                                                                                        135
# En alquiler                                                                                                                                        122
# En propiedad                                                                                                                                       122
# Otro régimen de tenencia                                                                                                                           122
# Trabajador por cuenta ajena fijo o indefinido                                                                                                      135
# Trabajador por cuenta ajena temporal                                                                                                               135
# Trabajador por cuenta propia que emplea personal                                                                                                   135
# Trabajador por cuenta propia que no emplea personal                                                                                                135
# SES_21                                                                                                                                             135
# kw_pct_21                                                                                                                                          135
# he_pct_21                                                                                                                                          135
# median_price_inf_21                                                                                                                                135
# dtype: int64

# %%
#Export
df_2011_left.to_csv(os.path.join(ruta, "df_2011_left.csv"),index=False,sep=";")
df_2021_left.to_csv(os.path.join(ruta, "df_2021_left.csv"),index=False,sep=";")

# %% [markdown]
# ## V2 Crear Dataset con 40 predictores -> 425 registros para 2011 / 115 registros para 2021

# %%
# Unir todos los DataFrames por la columna 'NUMSECCENS' utilizando reduce v2
ruta2 = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\Procesados\Secciones2"
dataframes_2011_v2 = []
dataframes_2021_v2 = []

# Iterar sobre los archivos en la ruta
for archivo in os.listdir(ruta2):
    # Verificar si el archivo es un CSV y comienza con el año
    if archivo.endswith('.csv') and archivo.startswith(anio_2011):
        # Leer el archivo y agregarlo a la lista de DataFrames
        df = pd.read_csv(os.path.join(ruta2, archivo),sep=";")
        dataframes_2011_v2.append(df)
        
        
    if archivo.endswith('.csv') and archivo.startswith(anio_2021):
        # Leer el archivo y agregarlo a la lista de DataFrames
        df = pd.read_csv(os.path.join(ruta2, archivo),sep=";")
        dataframes_2021_v2.append(df)

df_2011_v2 = reduce(lambda left, right: pd.merge(left, right, on="NUMSECCENS"), dataframes_2011_v2)
df_2021_v2 = reduce(lambda left, right: pd.merge(left, right, on="NUMSECCENS"), dataframes_2021_v2)

#Incluir scores
path_scores = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Scores\Scores-Secciones.csv"
df_scores = pd.read_csv(path_scores,sep=";")
df_scores_2011 =  df_scores[["NUMSECCENS","SES_11","kw_pct_11","he_pct_11","median_price_inf_11","RANK_11","SES_PR_11"]]
df_scores_2021 =  df_scores[["NUMSECCENS","SES_21","kw_pct_21","he_pct_21","median_price_inf_21","RANK_21","SES_PR_21"]]

df_2011_v2 = pd.merge(df_2011_v2, df_scores_2011, on='NUMSECCENS')
df_2021_v2 = pd.merge(df_2021_v2 , df_scores_2021, on='NUMSECCENS')

#print(df_2011_v2)#425rows x 43
#print(df_2021_v2)#115rows x 43

# %%
#Export
df_2011_v2.to_csv(os.path.join(ruta2, "df_2011.csv"),index=False,sep=";")
df_2021_v2.to_csv(os.path.join(ruta2, "df_2021.csv"),index=False,sep=";")
