# %%
import geopandas as gpd
import pandas as pd
import numpy as np

## Configuraciones Iniciales
estudios_distrito_2011_csv_path = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\Ocupados de 16 y más años_Estudios_Distritos_Censo_2011.csv"
estudios_distrito_2021_csv_path = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\Ocupados de 16 y más años_Estudios_Distritos_Censo_2021.csv"
estudios_detalle_distrito_2011_csv_path = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\Ocupados de 16 y más años_Estudios_Detalle_Distritos_Censo_2011.csv"
estudios_detalle_distrito_2021_csv_path = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\Ocupados de 16 y más años_Estudios_Detalle_Distritos_Censo_2021.csv"
cartografia_distrito_shp_path = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Shapefiles\da_cartografiaDistritoMunicipal-25830\da_cartografiaDistritoMunicipalPolygon.shp"

## Lectura inicial de datos estudios
df_estudios_distrito_2011 =  pd.read_csv(estudios_distrito_2011_csv_path,sep=";")
df_estudios_distrito_2021 =  pd.read_csv(estudios_distrito_2021_csv_path,sep=";")
df_estudios_detalle_distrito_2011 =  pd.read_csv(estudios_detalle_distrito_2011_csv_path,sep=";")
df_estudios_detalle_distrito_2021 =  pd.read_csv(estudios_detalle_distrito_2021_csv_path,sep=";")
df_cartografia_distrito = gpd.read_file(cartografia_distrito_shp_path)

# Ver las columnas
#print(df_estudios_distrito_2011.columns)
#print(df_estudios_distrito_2021.columns)
#print(df_estudios_detalle_distrito_2011.columns)
#print(df_estudios_detalle_distrito_2021.columns)
#print(df_cartografia_distrito.columns)

# Inspeccionar los primeros registros
#print(df_estudios_distrito_2011.head())
#print(df_estudios_distrito_2021.head())
#print(df_cartografia_distrito.head())

#Se realiza una normalizacion de los csv de estudios en dos columnas estudios y personas 
df_estudios_distrito_2011_long = pd.melt(df_estudios_distrito_2011, id_vars=["Municipio de residencia","Distrito de residencia"], var_name='Estudios', value_name='Personas')
#print(df_estudios_distrito_2011_long.columns)
#print(df_estudios_distrito_2011_long.head())
df_estudios_distrito_2021_long = pd.melt(df_estudios_distrito_2021, id_vars=["Municipio de residencia","Distrito "], var_name='Estudios', value_name='Personas')
#print(df_estudios_distrito_2021_long.columns)
#print(df_estudios_distrito_2021_long.head())
df_estudios_detalle_distrito_2011_long = pd.melt(df_estudios_detalle_distrito_2011, id_vars=["Municipio de residencia","Distrito de residencia"], var_name='Estudios', value_name='Personas')
#print(df_estudios_detalle_distrito_2011_long.columns)
#print(df_estudios_detalle_distrito_2011_long.head())
df_estudios_detalle_distrito_2021_long = pd.melt(df_estudios_detalle_distrito_2021, id_vars=["Municipio de residencia","Distrito "], var_name='Estudios', value_name='Personas')
#print(df_estudios_detalle_distrito_2021_long.columns)
#print(df_estudios_detalle_distrito_2021_long.head())

#Cambio el nombre de la columna 'Distrito ' a Distrito de residencia
df_estudios_distrito_2021_long.rename(columns={'Distrito ': 'Distrito de residencia'}, inplace=True)
df_estudios_detalle_distrito_2021_long.rename(columns={'Distrito ': 'Distrito de residencia'}, inplace=True)
#print(df_estudios_detalle_distrito_2011_long.head())
#print(df_estudios_detalle_distrito_2021_long.head())

# Mostrar información general sobre el DataFrame
#print(df_estudios_detalle_distrito_2011_long.info())
#print(df_estudios_detalle_distrito_2021_long.info())

#Contamos el numero de valores que hay en estos casos (Sabemos que los censo de 2011 tenia casos)
#Detalle
num_filas_en_blanco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].str.contains(r'\*')).sum()
#print(num_filas_en_blanco_detalle_2011)#0
#print(num_filas_con_asterisco_detalle_2011)#25
#General
num_filas_en_blanco_2011 = (df_estudios_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_2011 = (df_estudios_distrito_2011_long['Personas'].str.contains(r'\*')).sum()
#print(num_filas_en_blanco_2011)#0
#print(num_filas_con_asterisco_2011)#12

## Eliminar filas ##
#Eliminar filas de municipio Total
df_estudios_distrito_2011_long = df_estudios_distrito_2011_long [df_estudios_distrito_2011_long ['Municipio de residencia'] != 'Total']
df_estudios_distrito_2021_long = df_estudios_distrito_2021_long [df_estudios_distrito_2021_long ['Municipio de residencia'] != 'Total']
df_estudios_detalle_distrito_2011_long = df_estudios_detalle_distrito_2011_long [df_estudios_detalle_distrito_2011_long ['Municipio de residencia'] != 'Total']
df_estudios_detalle_distrito_2021_long = df_estudios_detalle_distrito_2021_long [df_estudios_detalle_distrito_2021_long ['Municipio de residencia'] != 'Total']
#Eliminamos las filas de residencia Total
df_estudios_distrito_2011_long = df_estudios_distrito_2011_long [df_estudios_distrito_2011_long ['Distrito de residencia'] != 'Total']
df_estudios_distrito_2021_long = df_estudios_distrito_2021_long [df_estudios_distrito_2021_long ['Distrito de residencia'] != 'Total']
df_estudios_detalle_distrito_2011_long = df_estudios_detalle_distrito_2011_long [df_estudios_detalle_distrito_2011_long ['Distrito de residencia'] != 'Total']
df_estudios_detalle_distrito_2021_long = df_estudios_detalle_distrito_2021_long [df_estudios_detalle_distrito_2021_long ['Distrito de residencia'] != 'Total']
#Eliminamos las filas de estudio Total 
df_estudios_distrito_2011_long = df_estudios_distrito_2011_long [df_estudios_distrito_2011_long ['Estudios'] != 'Total']
df_estudios_distrito_2021_long = df_estudios_distrito_2021_long [df_estudios_distrito_2021_long ['Estudios'] != 'Total']
df_estudios_detalle_distrito_2011_long = df_estudios_detalle_distrito_2011_long [df_estudios_detalle_distrito_2011_long ['Estudios'] != 'Total']
df_estudios_detalle_distrito_2021_long = df_estudios_detalle_distrito_2021_long [df_estudios_detalle_distrito_2021_long ['Estudios'] != 'Total']

#print(df_estudios_distrito_2011_long.head())
#print(df_estudios_distrito_2021_long.head())
#print(df_estudios_detalle_distrito_2011_long.head())
#print(df_estudios_detalle_distrito_2021_long.head())

## Añadir columnas ##
#Añadir columna NUMERO con el numero de distrito
df_estudios_distrito_2011_long["NUMERO"] = df_estudios_distrito_2011_long["Distrito de residencia"].str[-2:].astype(float)
df_estudios_distrito_2021_long["NUMERO"] = df_estudios_distrito_2021_long["Distrito de residencia"].str[-2:].astype(float)
df_estudios_detalle_distrito_2011_long["NUMERO"] = df_estudios_detalle_distrito_2011_long["Distrito de residencia"].str[-2:].astype(float)
df_estudios_detalle_distrito_2021_long["NUMERO"] = df_estudios_detalle_distrito_2021_long["Distrito de residencia"].str[-2:].astype(float)
#print(df_ocupacion_distrito_2011_long.columns)
#print(df_ocupacion_distrito_2021_long.columns)

## Gestion de Nulos y valores extraños ##
num_filas_en_blanco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].str.contains(r'\*')).sum()
num_filas_en_blanco_2011 = (df_estudios_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_2011 = (df_estudios_distrito_2011_long['Personas'].str.contains(r'\*')).sum()
#print(num_filas_en_blanco_detalle_2011)#0
#print(num_filas_con_asterisco_detalle_2011)#25
#print(num_filas_en_blanco_2011)#0
#print(num_filas_con_asterisco_2011)#12
# Limpiar los datos: eliminar el asterisco al final, pero dejar intacto el '*'
df_estudios_detalle_distrito_2011_long['Personas'] = df_estudios_detalle_distrito_2011_long['Personas'].replace(r'(\d+)\*$', r'\1', regex=True)
df_estudios_distrito_2011_long['Personas'] = df_estudios_distrito_2011_long['Personas'].replace(r'(\d+)\*$', r'\1', regex=True)
num_filas_en_blanco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].str.contains(r'\*')).sum()
num_filas_en_blanco_2011 = (df_estudios_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_2011 = (df_estudios_distrito_2011_long['Personas'].str.contains(r'\*')).sum()
#print(num_filas_en_blanco_detalle_2011)#0
#print(num_filas_con_asterisco_detalle_2011)#16
#print(num_filas_en_blanco_2011)#0
#print(num_filas_con_asterisco_2011)#0
#Sustituimos los valores * por NA
df_estudios_detalle_distrito_2011_long['Personas'] = df_estudios_detalle_distrito_2011_long['Personas'].replace('*', np.nan)
df_estudios_detalle_distrito_2021_long['Personas'] = df_estudios_detalle_distrito_2021_long['Personas'].replace('*', np.nan)
num_filas_en_blanco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].str.contains(r'\*')).sum()
#print(num_filas_en_blanco_detalle_2011)#16
#print(num_filas_con_asterisco_detalle_2011)#0
#Columna Personas como float
df_estudios_distrito_2011_long['Personas'] = df_estudios_distrito_2011_long['Personas'].astype(float)
df_estudios_distrito_2021_long['Personas'] = df_estudios_distrito_2021_long['Personas'].astype(float)
df_estudios_detalle_distrito_2011_long['Personas'] = df_estudios_detalle_distrito_2011_long['Personas'].astype(float)
df_estudios_detalle_distrito_2021_long['Personas'] = df_estudios_detalle_distrito_2021_long['Personas'].astype(float)
#En el censo de detalle 2011 tenemos valores nulos, vamos a ver si se desvia mucho el calculo si le ponemos un valor nosotros
# Calcular la desviación estándar antes de la imputación
desviacion_imputada_detalle_2011= df_estudios_detalle_distrito_2011_long.groupby('Distrito de residencia')['Personas'].std()
#print("Desviación estándar por distrito para estudios detalle antes de imputar 3:", desviacion_imputada_detalle_2011)
## Calcular % Personas estudios por distrito con valor medio 3 ##
#Los valores con * tienen un valor entre 1-5 según el INE. Utilizaremos la media (3) como estimacion
#No obstante vamos a ver si la desviacion del dato cambia mucho respecto a lo anterior usando el 3
df_estudios_detalle_distrito_2011_long['Personas'] = df_estudios_detalle_distrito_2011_long['Personas'].replace(np.nan, 3)
df_estudios_detalle_distrito_2021_long['Personas'] = df_estudios_detalle_distrito_2021_long['Personas'].replace(np.nan, 3)
#Contamos el numero de valores que hay en estos casos despues de los ajustes anteriores otra vez
num_filas_en_blanco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'].isna()).sum()
num_filas_con_asterisco_detalle_2011 = (df_estudios_detalle_distrito_2011_long['Personas'] == "*").sum()
#print(num_filas_en_blanco_detalle_2011)#0
#print(num_filas_con_asterisco_detalle_2011)#0
# Calcular la desviación estándar despues de la imputación 
desviacion_imputada_detalle_2011= df_estudios_detalle_distrito_2011_long.groupby('Distrito de residencia')['Personas'].std()
#print("Desviación estándar por distrito para estudios detalle despues de imputar 3:", desviacion_imputada_detalle_2011)
#No parece que la desviacion sea excesiva asi que podemos continuar con la imputacion de 3 en los nan.

##Calcular el total de personas por distrito y el porcentaje de Personas
df_estudios_detalle_distrito_2011_long['Total_personas_distrito'] = df_estudios_detalle_distrito_2011_long.groupby('Distrito de residencia')['Personas'].transform('sum')
df_estudios_detalle_distrito_2021_long['Total_personas_distrito'] = df_estudios_detalle_distrito_2021_long.groupby('Distrito de residencia')['Personas'].transform('sum')
#Calcular porcentaje sobre el total
df_estudios_detalle_distrito_2011_long['Personas %'] = (df_estudios_detalle_distrito_2011_long['Personas'] / df_estudios_detalle_distrito_2011_long['Total_personas_distrito'])
df_estudios_detalle_distrito_2021_long['Personas %'] = (df_estudios_detalle_distrito_2021_long['Personas'] / df_estudios_detalle_distrito_2021_long['Total_personas_distrito'])
#print(df_estudios_detalle_distrito_2011_long[df_estudios_detalle_distrito_2011_long['NUMERO'] == 1])
#print(df_estudios_detalle_distrito_2011_long[df_estudios_detalle_distrito_2011_long['NUMERO'] == 3])
#print(df_estudios_detalle_distrito_2011_long[df_estudios_detalle_distrito_2011_long['NUMERO'] == 5])
#print(df_estudios_detalle_distrito_2021_long[df_estudios_detalle_distrito_2021_long['NUMERO'] == 1])

## Unificar valores categorias Estudios en censos 2011 y 2021
#Estudios (General)
#Los valores que toma el campo Estudios son distintos en cada dataframe. Distintos tamaños
#print(df_estudios_distrito_2011_long['Estudios'].unique())
#print(df_estudios_distrito_2021_long['Estudios'].unique())
#Estudis (Detalle)
#Los valores que toma el campo Estudios son distintos en cada dataframe.
#print(df_estudios_detalle_distrito_2011_long['Estudios'].unique())#Tamaño 13
#print(df_estudios_detalle_distrito_2021_long['Estudios'].unique())#Tamaño 13

#Vamos a mapear las categorias detalle de 2011 a 2021

# Diccionario de mapeo 2011 a 2021
mapping_dict_2011_2021 = {
    'Total': 'Total',
    'Analfabetos': 'Analfabetos',
    'Sin estudios': 'Estudios primarios incompletos',
    'Fue a la escuela 5 años o más pero no llegó al último curso de ESO, EGB o Bachiller Elemental': 'Educación primaria',
    'Llegó al último curso de ESO, EGB o Bachiller Elemental o tiene el Certificado de Escolaridad o de Estudios Primarios': 'Primera etapa de educación secundaria y similar',
    'Bachiller, BUP, Bachiller Superior, COU, PREU': 'Segunda etapa de educación secundaria con orientación general',
    'FP grado medio, FP I, Oficialia Industrial o equivalente, Grado Medio de Música y Danza, Certificados de Escuelas Oficiales de Idiomas': 'Segunda etapa de educación secundaria con orientación profesional',
    'FP grado superior, FPII, Maestria industrial o equivalente': 'Educación postsecundaria no superior',
    'Diplomatura universitaria, Aquitectura Técnica, Ingeniería Técnica o equivalente': 'Enseñanzas de formación profesional, artes plásticas y diseño y deportivas de grado superior y equivalentes',
    'Grado Universitario o equivalente': 'Grados universitarios de 240 créditos ECTS, diplomados universitarios, títulos propios universitarios de experto o especialista',
    'Licenciatura, Arquitectura, Ingeniería o equivalente': 'Grados universitarios de más de 240 créditos ECTS, licenciados',
    'Máster oficial univeritario (a partir de 2006) , Especialidades Médicas o análogas': 'Másteres, especialidades en Ciencias de la Salud por el sistema de residencia y similares',
    'Doctorado': 'Doctorado universitario'
}

df_estudios_detalle_distrito_2011_long['Estudios'] = df_estudios_detalle_distrito_2011_long['Estudios'].map(mapping_dict_2011_2021)
#print(df_estudios_detalle_distrito_2011_long['Estudios'].unique())
#print(df_estudios_detalle_distrito_2021_long['Estudios'].unique())

#Crear nueva columna Id_Estudios
mapping_dict_estudios_id_estudios = {
    'Total': -1,
    'Analfabetos': 1,
    'Estudios primarios incompletos': 2,
    'Educación primaria': 3,
    'Primera etapa de educación secundaria y similar': 4,
    'Segunda etapa de educación secundaria con orientación general': 5,
    'Segunda etapa de educación secundaria con orientación profesional': 6,
    'Educación postsecundaria no superior': 7,
    'Enseñanzas de formación profesional, artes plásticas y diseño y deportivas de grado superior y equivalentes': 8,
    'Grados universitarios de 240 créditos ECTS, diplomados universitarios, títulos propios universitarios de experto o especialista': 9,
    'Grados universitarios de más de 240 créditos ECTS, licenciados' : 10,
    'Másteres, especialidades en Ciencias de la Salud por el sistema de residencia y similares':  11,
    'Doctorado universitario': 12
}

df_estudios_detalle_distrito_2011_long['Id_Estudios'] = df_estudios_detalle_distrito_2011_long['Estudios'].map(mapping_dict_estudios_id_estudios).astype(float)
df_estudios_detalle_distrito_2021_long['Id_Estudios'] = df_estudios_detalle_distrito_2021_long['Estudios'].map(mapping_dict_estudios_id_estudios).astype(float)

print(df_estudios_detalle_distrito_2011_long.head())
print(df_estudios_detalle_distrito_2021_long.head())

#Incluir campos de geolocalizacion
#2011
df_estudios_detalle_distrito_2011_long_mapped = pd.merge(df_estudios_detalle_distrito_2011_long, df_cartografia_distrito, on='NUMERO')
#print(df_estudios_detalle_distrito_2011_long_mapped )
#2021
df_estudios_detalle_distrito_2021_long_mapped = pd.merge(df_estudios_detalle_distrito_2021_long, df_cartografia_distrito, on='NUMERO')
#print(df_estudios_detalle_distrito_2021_long_mapped)

# Export
columnas_exportacion= ['NOMBRE', 'Estudios', 'Id_Estudios', 'Personas %', 'ID_DISMUNI', 'NUMERO', 'geometry']
df_estudios_detalle_distrito_2011_long_mapped_export = df_estudios_detalle_distrito_2011_long_mapped[columnas_exportacion]
df_estudios_detalle_distrito_2021_long_mapped_export = df_estudios_detalle_distrito_2021_long_mapped[columnas_exportacion]

df_estudios_detalle_distrito_2011_long_mapped_export_path = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\2011_Distritos_Estudios_Detalle.csv"
df_estudios_detalle_distrito_2021_long_mapped_export_path = r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\2021_Distritos_Estudios_Detalle.csv"
#df_estudios_detalle_distrito_2011_long_mapped_export.to_csv(df_estudios_detalle_distrito_2011_long_mapped_export_path,index=False,sep=";")
#df_estudios_detalle_distrito_2021_long_mapped_export.to_csv(df_estudios_detalle_distrito_2021_long_mapped_export_path,index=False,sep=";")

#Export 2 estudios top
#Los estudios top estan entre el id 9 al 12 (equivalente a NVQ4 o superior)
df_estudios_detalle_distrito_2011_long_mapped_only_high_educated = df_estudios_detalle_distrito_2011_long_mapped[df_estudios_detalle_distrito_2011_long_mapped['Id_Estudios'].isin([ 9, 10, 11, 12])]
df_estudios_detalle_distrito_2021_long_mapped_only_high_educated = df_estudios_detalle_distrito_2021_long_mapped[df_estudios_detalle_distrito_2021_long_mapped['Id_Estudios'].isin([ 9, 10, 11, 12])]

# Agrupar por distrito y sumar 'Personas' y 'Porcentaje'
df_agrupado_2011 = df_estudios_detalle_distrito_2011_long_mapped_only_high_educated.groupby(['NOMBRE','Distrito de residencia','NUMERO'], as_index=False).agg({
    'Personas %': 'sum'
})

df_agrupado_2021 = df_estudios_detalle_distrito_2021_long_mapped_only_high_educated.groupby(['NOMBRE','Distrito de residencia','NUMERO'], as_index=False).agg({
    'Personas %': 'sum'
})

#Renombrar columna
df_agrupado_2011.rename(columns={'Personas %': 'he_pct'}, inplace=True)
df_agrupado_2021.rename(columns={'Personas %': 'he_pct'}, inplace=True)

print(df_agrupado_2011)
print(df_agrupado_2021)

df_agrupado_2011.to_csv(r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\2011_Distritos_Estudios_Detalle_V2.csv",index=False,sep=";")
df_agrupado_2021.to_csv(r"C:\Users\Usuario\OneDrive\Escritorio\UOC\TFM\PEC3  - Implementacion\WorkStation\Datos\Variables\04  - Estudios\Distritos\2021_Distritos_Estudios_Detalle_V2.csv",index=False,sep=";")
# Out:
#    Municipio de residencia Distrito de residencia     Estudios  Personas  \
# 15            29067 Málaga       Distrito 2906702  Analfabetos      95.0
# 16            29067 Málaga       Distrito 2906704  Analfabetos      50.0
# 17            29067 Málaga       Distrito 2906706  Analfabetos      40.0
# 18            29067 Málaga       Distrito 2906707  Analfabetos      35.0
# 19            29067 Málaga       Distrito 2906708  Analfabetos      30.0
#
#     NUMERO  Total_personas_distrito  Personas %  Id_Estudios
# 15     2.0                  25250.0    0.003762          1.0
# 16     4.0                   5610.0    0.008913          1.0
# 17     6.0                  19125.0    0.002092          1.0
# 18     7.0                  34960.0    0.001001          1.0
# 19     8.0                  37695.0    0.000796          1.0
#    Municipio de residencia Distrito de residencia     Estudios  Personas  \
# 15            29067 Málaga       Distrito 2906701  Analfabetos       0.0
# ...

# %% [markdown]
# | **Censo 2011**                                                                                             | **Censo 2021**                                                                                                      |
# |--------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------------|
# | **Total**                                                                                                | **Total**                                                                                                        |
# | **Analfabetos**                                                                                          | **Analfabetos**                                                                                                  |
# | **Sin estudios**                                                                                         | **Estudios primarios incompletos**                                                                               |
# | **Fue a la escuela 5 años o más pero no llegó al último curso de ESO, EGB o Bachiller Elemental**        | **Educación primaria**                                                                                           |
# | **Llegó al último curso de ESO, EGB o Bachiller Elemental o tiene el Certificado de Escolaridad**       | **Primera etapa de educación secundaria y similar**                                                              |
# | **Bachiller, BUP, Bachiller Superior, COU, PREU**                                                        | **Segunda etapa de educación secundaria con orientación general**                                                |
# | **FP grado medio, FP I, Oficialia Industrial o equivalente, Grado Medio de Música y Danza, Escuelas de Idiomas** | **Segunda etapa de educación secundaria con orientación profesional**                                            |
# | **FP grado superior, FPII, Maestría industrial o equivalente**                                           | **Educación postsecundaria no superior**                                                                          |
# | **Diplomatura universitaria, Arquitectura Técnica, Ingeniería Técnica o equivalente**                   | **Enseñanzas de formación profesional, artes plásticas y diseño y deportivas de grado superior y equivalentes**   |
# | **Grado Universitario o equivalente**                                                                    | **Grados universitarios de 240 créditos ECTS, diplomados universitarios, títulos propios universitarios de experto o especialista** |
# | **Licenciatura, Arquitectura, Ingeniería o equivalente**                                                 | **Grados universitarios de más de 240 créditos ECTS, licenciados**                                               |
# | **Máster oficial universitario (a partir de 2006), Especialidades Médicas o análogas**                  | **Másteres, especialidades en Ciencias de la Salud por el sistema de residencia y similares**                    |
# | **Doctorado**                                                                                           | **Doctorado universitario**                                                                                        |
